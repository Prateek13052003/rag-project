# %%
pip install groq
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: groq in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (0.33.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (2.12.4)
# Requirement already satisfied: sniffio in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from groq) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: certifi in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->groq) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/prateekchoudhary/Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
from groq import Groq

load_dotenv()

client = Groq(api_key=os.getenv("GROQ_API_KEY"))
models = client.models.list()

for m in models.data:
    print(m.id)
# Out:
# whisper-large-v3
# meta-llama/llama-4-scout-17b-16e-instruct
# llama-3.3-70b-versatile
# groq/compound-mini
# whisper-large-v3-turbo
# allam-2-7b
# openai/gpt-oss-safeguard-20b
# openai/gpt-oss-120b
# groq/compound
# playai-tts
# meta-llama/llama-prompt-guard-2-22m
# llama-3.1-8b-instant
# qwen/qwen3-32b
# openai/gpt-oss-20b
# moonshotai/kimi-k2-instruct
# moonshotai/kimi-k2-instruct-0905
# meta-llama/llama-prompt-guard-2-86m
# playai-tts-arabic
# meta-llama/llama-guard-4-12b
# meta-llama/llama-4-maverick-17b-128e-instruct
